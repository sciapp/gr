# %%
import numpy as np

# %%
from gr.pygr import *

# %%
import gr

# %%
gr.inline("mov")

# %%
x=np.linspace(0,2*np.pi,500)

# %%
for i in range(200):
    plot(x, np.sin(x + i / 10.0))

# %%
gr.show()
# Out:
# <video controls autoplay type="video/mp4" src="data:video/mp4;base64,...">
